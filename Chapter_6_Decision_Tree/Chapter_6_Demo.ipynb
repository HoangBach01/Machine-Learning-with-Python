# %%
from google.colab import drive
drive.mount("/content/gdrive")
# %cd '/content/gdrive/MyDrive/LDS6_S7N_TranHoangBach/BaiTap/Chapter_6_Decision_Tree'
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/LDS6_S7N_TranHoangBach/BaiTap/Chapter_6_Decision_Tree

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, export_graphviz
from sklearn.model_selection import train_test_split
from IPython.display import Image
from six import StringIO
import pydotplus
import graphviz

# %%
df = pd.read_excel('data/Iris.xls')
df
# Out:
#      sepallength  sepalwidth  petallength  petalwidth            iris
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
X = df.drop(columns=['iris'])
y = df['iris']
X
# Out:
#      sepallength  sepalwidth  petallength  petalwidth
# 0            5.1         3.5          1.4         0.2
# 1            4.9         3.0          1.4         0.2
# 2            4.7         3.2          1.3         0.2
# 3            4.6         3.1          1.5         0.2
# 4            5.0         3.6          1.4         0.2
# ..           ...         ...          ...         ...
# 145          6.7         3.0          5.2         2.3
# 146          6.3         2.5          5.0         1.9
# 147          6.5         3.0          5.2         2.0
# 148          6.2         3.4          5.4         2.3
# 149          5.9         3.0          5.1         1.8
#
# [150 rows x 4 columns]

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
# print(X_train.shape)
# print(y_test.shape)

# %%
clf = DecisionTreeClassifier()
clf.fit(X, y)
clf.score(X, y)
# Out:
# 1.0

# %%
dot_data = export_graphviz(clf, out_file=None, 
                                feature_names=X.columns,
                                filled=True,
                                rounded=True,
                                )
graph = pydotplus.graph_from_dot_data(dot_data)  
Image(graph.create_png())

# %%
# !pip install pandas-profiling==2.7.1

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# %cd '/content/gdrive/MyDrive/LDS6_S7N_TranHoangBach/BaiTap/Chapter_2'
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/LDS6_S7N_TranHoangBach/BaiTap/Chapter_2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import pandas_profiling as pp
# %matplotlib inline

# %%
df = pd.read_csv('data/retail.csv', index_col='Unnamed: 0')
df
# Out:
#       CustomerID  Year  ...  Country_United Kingdom  Country_Unspecified
# 0        12346.0  2011  ...                       1                    0
# 1        12347.0  2010  ...                       0                    0
# 2        12347.0  2011  ...                       0                    0
# 3        12348.0  2010  ...                       0                    0
# 4        12348.0  2011  ...                       0                    0
# ...          ...   ...  ...                     ...                  ...
# 5099     18280.0  2011  ...                       1                    0
# 5100     18281.0  2011  ...                       1                    0
# 5101     18282.0  2011  ...                       2                    0
# 5102     18283.0  2011  ...                      16                    0
# 5103     18287.0  2011  ...                       3                    0
#
# [5104 rows x 3718 columns]

# %%
df
# Out:
#       CustomerID  Year  ...  Country_United Kingdom  Country_Unspecified
# 0        12346.0  2011  ...                       1                    0
# 1        12347.0  2010  ...                       0                    0
# 2        12347.0  2011  ...                       0                    0
# 3        12348.0  2010  ...                       0                    0
# 4        12348.0  2011  ...                       0                    0
# ...          ...   ...  ...                     ...                  ...
# 5099     18280.0  2011  ...                       1                    0
# 5100     18281.0  2011  ...                       1                    0
# 5101     18282.0  2011  ...                       2                    0
# 5102     18283.0  2011  ...                      16                    0
# 5103     18287.0  2011  ...                       3                    0
#
# [5104 rows x 3718 columns]

# %%
X = df[df['Year']==2010].groupby('CustomerID').sum().reset_index()
X = X.rename(columns={'Revenue': '2010 Revenue'})
X
# Out:
#      CustomerID  Year  ...  Country_United Kingdom  Country_Unspecified
# 0       12347.0  2010  ...                       0                    0
# 1       12348.0  2010  ...                       0                    0
# 2       12370.0  2010  ...                       0                    0
# 3       12377.0  2010  ...                       0                    0
# 4       12383.0  2010  ...                       0                    0
# ..          ...   ...  ...                     ...                  ...
# 880     18239.0  2010  ...                       1                    0
# 881     18245.0  2010  ...                       1                    0
# 882     18259.0  2010  ...                       1                    0
# 883     18260.0  2010  ...                       1                    0
# 884     18269.0  2010  ...                       1                    0
#
# [885 rows x 3718 columns]

# %%
y = df[df['Year']==2011][['CustomerID', 'Revenue']].groupby('CustomerID').sum().reset_index()
y = y.rename(columns={'Revenue': '2011 Revenue'})
y
# Out:
#       CustomerID  2011 Revenue
# 0        12346.0      77183.60
# 1        12347.0       3598.21
# 2        12348.0        904.44
# 3        12349.0       1757.55
# 4        12350.0        334.40
# ...          ...           ...
# 4214     18280.0        180.60
# 4215     18281.0         80.82
# 4216     18282.0        178.05
# 4217     18283.0       2094.88
# 4218     18287.0       1837.28
#
# [4219 rows x 2 columns]

# %%
data = pd.merge(X, y, how='inner', on='CustomerID')
data
# Out:
#      CustomerID  Year  ...  Country_Unspecified  2011 Revenue
# 0       12347.0  2010  ...                    0       3598.21
# 1       12348.0  2010  ...                    0        904.44
# 2       12370.0  2010  ...                    0       1677.67
# 3       12377.0  2010  ...                    0        626.60
# 4       12383.0  2010  ...                    0       1249.84
# ..          ...   ...  ...                  ...           ...
# 761     18229.0  2010  ...                    0       6623.70
# 762     18239.0  2010  ...                    0       1123.51
# 763     18245.0  2010  ...                    0       2201.33
# 764     18259.0  2010  ...                    0       1962.30
# 765     18260.0  2010  ...                    0       2412.50
#
# [766 rows x 3719 columns]

# %%
from sklearn.model_selection import train_test_split
X = data.drop('2011 Revenue', axis=1)
y = data['2011 Revenue']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()
X_train = std_scaler.fit_transform(X_train)
X_test = std_scaler.transform(X_test)
print(X_train.shape)
print(y_test.shape)
# Out:
# (574, 3718)
# (192,)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# -11.61189719458547

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.models import Sequential

model = Sequential([
                    BatchNormalization(),
                    Dense(256, activation='relu'),
                    Dropout(0.4),
                    BatchNormalization(),
                    Dense(128, activation='relu'),
                    Dropout(0.4),
                    BatchNormalization(),
                    Dense(64, activation='relu'),
                    Dropout(0.4),
                    BatchNormalization(),
                    Dense(32, activation='relu'),
                    Dropout(0.4),
                    BatchNormalization(),                    
                    Dense(1)
])

call_back = tf.keras.callbacks.ModelCheckpoint('model_nn.h5', save_best_only=True, mode='max')
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=0.01))
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, verbose=2, callbacks=[call_back])
print('\n')
model.evaluate(X_test, y_test)

from sklearn.metrics import r2_score
print('R2 - train: {:.4f}'.format(r2_score(y_train, model.predict(X_train))))
print('R2 - test: {:.4f}'.format(r2_score(y_test, model.predict(X_test))))
# Out:
# Epoch 1/100
# 18/18 - 2s - loss: 404220096.0000 - val_loss: 136606912.0000
# Epoch 2/100
# 18/18 - 0s - loss: 404190784.0000 - val_loss: 136628624.0000
# Epoch 3/100
# 18/18 - 0s - loss: 404128672.0000 - val_loss: 136530544.0000
# Epoch 4/100
# 18/18 - 0s - loss: 404019904.0000 - val_loss: 136808176.0000
# Epoch 5/100
# 18/18 - 0s - loss: 403855712.0000 - val_loss: 136532688.0000
# Epoch 6/100
# 18/18 - 0s - loss: 403559168.0000 - val_loss: 135986208.0000
# Epoch 7/100
# 18/18 - 0s - loss: 403314720.0000 - val_loss: 135469936.0000
# Epoch 8/100
# 18/18 - 0s - loss: 402911936.0000 - val_loss: 136164688.0000
# Epoch 9/100
# 18/18 - 0s - loss: 402601248.0000 - val_loss: 136349232.0000
# Epoch 10/100
# 18/18 - 0s - loss: 402118784.0000 - val_loss: 136371760.0000
# Epoch 11/100
# 18/18 - 0s - loss: 401393600.0000 - val_loss: 136391536.0000
# Epoch 12/100
# 18/18 - 0s - loss: 400721568.0000 - val_loss: 136928928.0000
# Epoch 13/100
# ...

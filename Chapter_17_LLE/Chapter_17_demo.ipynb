# %%
from google.colab import drive
drive.mount("/content/gdrive")
# %cd '/content/gdrive/MyDrive/LDS6_S7N_TranHoangBach/BaiTap/Chapter_17_LLE'
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/LDS6_S7N_TranHoangBach/BaiTap/Chapter_17_LLE

# %%
from sklearn.datasets import make_swiss_roll

# %%
X, y = make_swiss_roll(1000, 0.1)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(1, 1, 1, projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap=plt.cm.hsv)
plt.show()

# %%
from sklearn.manifold import LocallyLinearEmbedding
lle = LocallyLinearEmbedding(
    n_components=2, 
    n_neighbors=5,
)
X_lle = lle.fit_transform(X)
plt.scatter(X[:, 0], X[:, 1], c=y)
